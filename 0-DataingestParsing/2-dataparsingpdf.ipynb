# %% [markdown]
# ### Load PDF Files

# %%
from langchain_community.document_loaders import(
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader
)

# %%
# Method 1
# PyPDF Loader

try:
    pypdf_loader = PyPDFLoader('data/pdf_files/AI_Transformation_Playbook.pdf')
    pypdf_docs = pypdf_loader.load()
    print(pypdf_docs)
    print(f"Loaded {len(pypdf_docs)} pages")
    print(f" Page 1 Content ; {pypdf_docs[0].page_content[:100]}...")
    print(f'Metadata: {pypdf_docs[0].metadata}')

except Exception as e:
    print(f" Error: {e}")
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 19.2 (Macintosh)', 'creationdate': '2024-02-23T14:55:51-05:00', 'moddate': '2024-02-23T14:57:41-05:00', 'trapped': '/False', 'source': 'data/pdf_files/AI_Transformation_Playbook.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='© DeepLearning.AI  All rights reserved. | deeplearning.ai 1\nAI (Artificial Intelligence) technology is now \npoised to transform every industry, just as \nelectricity did 100 years ago. Between now and \n2030, it will create an estimated $13 trillion \nof GDP growth.1 While it has already created \ntremendous value in leading technology \ncompanies such as Google, Baidu, Microsoft and \nFacebook, much of the additional waves of value \ncreation will go beyond the software sector. \nThis AI Transformation Playbook draws on \ninsights gleaned from leading the Google Brain \nteam and the Baidu AI Group, which played \nleading roles in transforming both Google 
# ...

# %%
# Method 2 : PyMuPDFLoader

try:
    pymupdf_loader = PyMuPDFLoader('data/pdf_files/AI_Transformation_Playbook.pdf')
    pymupdf_docs = pymupdf_loader.load()

    print(f'Loaded {len(pymupdf_docs)} pages')
    print(pymupdf_docs)
except Exception as e:
    print(f'Error :{e}')
# Out:
# Loaded 6 pages
# ...

# %% [markdown]
# ### Handling PDF Challenges
# - 1. Store text in complex ways (not just simple text)
# - 2. Can have formatting issues
# - 3. May contain scanned images (requiring OCR)
# - 4. Often have extraction artifacts

# %%
# Example of raw PDF extraction
raw_pdf_text ="""AI Transformation Playbook


 How to lead your company into the AI era by Andrew Ng

 AI (Artificial Intelligence) technology is now 
poised to transform every industry, just as 
electricity did 100 years ago.

Page 1 of 6
"""

# Apply the cleaning function
def clean_text(text):
    text = " ".join(text.split())  # Removing excessive whitespace

    return text

cleaned = clean_text(raw_pdf_text)

print('Before:')
print(repr(raw_pdf_text[:100]))
print('After:')
print(repr(cleaned[:100]))

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
class SmartPDFProcessor:
    """Advanced PDF Processing with error handling"""
    def __init__(self, chunk_size=1000,chunk_overlap=100):
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size = chunk_size
            chunk_overlap = chunk_overlap
            separators=[" "]
        )

# %%
2+2
